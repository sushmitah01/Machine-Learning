# %%
import pandas as pd

# %%
a = [1, 7, 2]

myvar = pd.Series(a)

print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
print (myvar[0])
# Out:
# 1

# %%
a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
print(myvar["y"])
# Out:
# 7

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories, index = ["day1", "day2"])

print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %% [markdown]
# # Data Frames
# Series is like a column, a DataFrame is the whole **table**

# %%
data={
    "calories":[420, 380,390],
    "duration":[50, 40, 45]
}
#load data into a DataFrame Object
myvar = pd.DataFrame(data)

print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
#refer to the row index
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
#to locate rows
print(df.loc[[0,1]])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %%
data ={
    "calories":[420, 380,390],
    "duration":[50,40,45]
}
df=pd.DataFrame(data,index=["day1", "day2","day3"])

print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
#refer to the named index
print(df.loc["day2"])
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %% [markdown]
# Load Files into a Data Frame:
#
# if data sets are **sorted** in a file Pandas can load them into a DataFrame

# %%
df=pd.read_csv('data_csv') #Load a comma separated file (CSV file) into a DataFrame:
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-409333111.py in <cell line: 0>()
# ----> 1 df=pd.read_csv('data_csv') #Load a comma separated file (CSV file) into a DataFrame:
#       2 print(df)
#
# ...

# %%
print (df.to_string()) #to print the entire DataFrame

# %%
df=pd.read_csv('data_csv')
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-818160171.py in <cell line: 0>()
# ----> 1 df=pd.read_csv('data_csv')
#       2 print(df)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
print(df) #prin t the dataframe without the to_string() method

# %%
print(pd.options.display.max_rows) #check the number of maximum returned rows

# %%
pd.options.display.max_rows = 9999

df = pd.read_csv('data.csv')

print(df)  #NORMALLY IT ONLY SHOWS 5 ROWS BUT WHEN WE SET IT TO A SPECIFIC NUMBER IT RETURNS THAT

# %% [markdown]
# Pandas read JSON
#
# JSON is plain text but has the format of an object
# JSON = Python Dictionary

# %%
df=pd.read_json('data.json')
print(df.to_string())

# %% [markdown]
# if JSON code not in a file but in dictionary it can be loaded Directly

# %%
data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %% [markdown]
# # Analyzing DataFrames

# %% [markdown]
# To get a quick overview use head() method
#
# like to get a review of first 10 rows

# %%
df=pd.read_csv('data_csv')
print(df.head(10)) #if number bnot specified it would read first 5 rows

# %% [markdown]
# for reveiwing the **last rows** tail() method is used (from bottom)

# %%
print(df.tail)

#for more information about data info() method is used

print(pd.info())

# %% [markdown]
# # ** Data Cleaning  **
#
#
# *   Empty Cells
# *   Data in wrong format
# *   Wrong Data
# *   Duplicates

# %%
#remove rows
df = pd.read_csv('data.csv')

new_df = df.dropna() #By default, the dropna() method returns a new DataFrame, and will not change the original.

print(new_df.to_string())

# %% [markdown]
# to change the original DataFrame, use the **inplace = True ** argument:

# %%
df=pd.read_csv('data.csv')
df.dropna(inplace = True)
print(df.to_string()) #it removes all null values from original data frame insted of creating a new one

# %% [markdown]
# to replace empty values with a value use **fillna()** method

# %%
df=pd.read_csv('data_csv')
df.fillna(130,inplace=True) #REPLACE NULL VALUES WITH NUMBER  30

# %% [markdown]
# To only replace empty values for **one column**, specify the column name for the DataFrame:

# %%
df=pd.read_csv('data_csv')
df["Calories"].fillna(130,inplace=True) # Replace NULL values in the "Calories" columns with the number 130

# %% [markdown]
# # Mean, Median, Mode
#
#
# *   Mean= the average value

# %%
df = pd.read_csv('data.csv') # Calculate the MEAN, and replace any empty values with i

x = df["Calories"].mean()

df.fillna({"Calories": x}, inplace=True)

# %% [markdown]
# Calculate the **MEDIAN** and replace any empty values with it:
#
#
# *   **Median** = the value in the middle, after you have sorted all values ascending.

# %%
df = pd.read_csv('data.csv')

x = df["Calories"].median()

df.fillna({"Calories": x}, inplace=True)

# %% [markdown]
# Mode = the value that appears most frequently.

# %%
df = pd.read_csv('data.csv')

x = df["Calories"].mode()[0] #if theres multiple frequent values it will take the first one [0]

df.fillna({"Calories": x}, inplace=True)

# %% [markdown]
# # Cleaning Wrong **Format**

# %%
#
df = pd.read_csv('data.csv')

df['Date'] = pd.to_datetime(df['Date'], format='mixed')

print(df.to_string())

# %%
#remove rows with a null value
df.dropna(subset=['Date'], inplace = True)

# %% [markdown]
# # Fixing Wrong Data

# %%
df.loc[7, 'Duration']=45 #row 7, value 45

# %% [markdown]
# To fix values in **multiple rows**

# %%
#loop through them
#for example
for x in df.index:
  if df.loc[x, "Duration"] > 120:
    df.loc[x, "Duration"] = 120

# %% [markdown]
# **Delete** Rows

# %%
#deleting rows
for x in df.index:
  if df.loc[x, "Duration"] > 120:
    df.drop(x, inplace = True)

# %% [markdown]
# # Removing Dupolicates

# %% [markdown]
# **To discover duplicates**

# %%
print(df.duplicated())#retuns true for every row that is duplicate, otherwise False

# %% [markdown]
# now **to drop that** duplicates

# %%
df.drop_duplicates(inplace = True)

# %% [markdown]
# # **Correlations : Finding Relationships **
#
# **corr()** relationship between columns
# df.corr() #ignores **not numeric **values
# **Note:**
# The number varies from -1 to 1.
#
# 1 means that there is a 1 to 1 relationship (a perfect correlation),
#
# The number varies from -1 to 1.(more its closer to +1 its good otherwise bad
# A good correlation between at least -0.6 to 0.6

# %%
df.corr()

# %% [markdown]
# # **Plotting** in pandas

# %%
import pandas as pd
import matplotlibv.pyplot as plt

df = pd.read_csv('data.csv')

df.plot()

plt.show()

# %% [markdown]
# Scatter Plot using kind='scatter'
# Note
# x and y axis

# %%
df = pd.read_csv('data.csv')

df.plot(kind = 'scatter', x = 'Duration', y = 'Calories')

plt.show()

# %% [markdown]
# **Histogram**
# kind='hist'
# Note:
# only 1 column, frequency of each interval like from 30-60 how many people visted the store

# %%
df["Duration"].plot(kind = 'hist')

# %% [markdown]
# # ***Done and Dusted with Pandas for now***
